# %%
# 各stationの1日あたりの貸出台数, 返却台数を格納したDataFrameの作成
trip_count = table.station[["station_id","installation"]].copy()
trip_count["Days"] = (pd.Timestamp("2016-08-31") - trip_count["installation"]).dt.days
trip_count = trip_count.drop("installation", axis=1)
trip_count = trip_count.set_index("station_id")
trip_count["Rental Count"] = table.trip.groupby("Start Terminal").size()
trip_count["Rental per Day"] = trip_count["Rental Count"] / trip_count["Days"]
trip_count["Return Count"] = table.trip.groupby("End Terminal").size()
trip_count["Return per Day"] = trip_count["Return Count"] / trip_count["Days"]
trip_count["Total Count"] =trip_count["Rental Count"] + trip_count["Return Count"]
trip_count["Total per Day"] = trip_count["Total Count"] / trip_count["Days"]
trip_count = trip_count.sort_values("Total per Day", ascending=False)
trip_count.reset_index(level=0, inplace=True)

total_count_data = trip_count[["Total per Day"]].sort_values(by=["Total per Day"], ascending=True).reset_index(drop=True)

# 標準化
from sklearn.preprocessing import StandardScaler

sc0 = StandardScaler()
sc0.fit(total_count_data)
total_count_data_std = sc0.transform(total_count_data)

from sklearn.cluster import KMeans

X0 = total_count_data_std

# エルボー法
dist_list0 =[]
for i in range(1,20):
    kmpp0 = KMeans(n_clusters=i,init='random',n_init=5,max_iter=100,random_state=0)
    kmpp0.fit(X0)
    dist_list0.append(kmpp0.inertia_)
plt.plot(range(1,20),dist_list0,marker='+')
plt.xlabel("Number of clusters")
plt.ylabel("Disttortion")

# %%
# random_state固定
kmeans0 = KMeans(init='random',n_clusters=5,random_state=94) #n_clusters=4,random_state=29
kmeans0.fit(X0)
labels0 = kmeans0.labels_
label_data0 = pd.DataFrame(labels0,columns=["cl_nm"])
clusters_data0 = pd.concat([total_count_data,label_data0],axis=1)

for_merge_data0=pd.merge(trip_count[["station_id","Total per Day"]],clusters_data0,on=["Total per Day"]).sort_values(by=["station_id"],ascending=True)
merge_data0 = pd.merge(table.station,for_merge_data0,on=["station_id"])

import gmaps
gmaps.configure(api_key="AIzaSyARmLcIEdT5FC9PEBvNv2nFCVgTMw7NTT0")
fig = gmaps.figure(center=(37.491405, -122.233051), zoom_level=9)

cl_nm_list=[4,3,2,1,0]
color_list = ["rgba(255,69,0,1)", "rgba(255,140,0,1)", "rgba(255,255,0,1)", "rgba(50,205,50, 1)", "rgba(30,144,255, 1)"]

for i in range(len(cl_nm_list)):
    cl_nm=cl_nm_list[i]
    color = color_list[i]
    clusters = np.array(merge_data0[merge_data0.cl_nm == cl_nm][["lat", "long"]])
    cl_nm_layer= gmaps.symbol_layer(clusters, fill_color=color, stroke_color=color, scale=2)
    fig.add_layer(cl_nm_layer)

print("１日当たりのバイクの利用回数が多いところほど赤い")
fig
# Out:
# １日当たりのバイクの利用回数が多いところほど赤い
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %%
merge_data0["installation year"]=merge_data0["installation"].map(lambda x:x.year)

import gmaps
gmaps.configure(api_key="AIzaSyARmLcIEdT5FC9PEBvNv2nFCVgTMw7NTT0")
fig = gmaps.figure(center=(37.491405, -122.233051), zoom_level=9)

installation_year_list=[2016,2015,2014,2013]
color_list = ["rgba(255,69,0,1)", "rgba(255,255,0,1)", "rgba(50,205,50, 1)", "rgba(30,144,255, 1)"]

for i in range(len(installation_year_list)):
    installation_year=installation_year_list[i]
    color = color_list[i]
    clusters = np.array(merge_data0[merge_data0["installation year"] == installation_year][["lat", "long"]])
    installation_year_layer= gmaps.symbol_layer(clusters, fill_color=color, stroke_color=color, scale=2)
    fig.add_layer(installation_year_layer)


print("\t\tred : 2016\t", "\tyello : 2015\t", "\tgreen : 2014\t", "\tblue : 2013")
fig
# Out:
# 		red : 2016	 	yello : 2015	 	green : 2014	 	blue : 2013
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %% [markdown]
# # 機械学習によるstatus予測
# 目的変数：bikes_available(不足, 現状維持, 過多の3つのカテゴリに分類) ＊回帰だとscore0.4台...
# 説明変数：時間帯, 曜日, 天候
# 余裕があれば, 他のstationの貸出状況も考慮したRNNを用いた時系列データ解析も行う(バスケット分析の結果を利用).

# %% [markdown]
# ## モジュールのインポート
#
# table.ipynbをモジュールとして読み込み, CSVファイルの内容ごとに結合・前処理したDataFrameにアクセスする．
#
# 主なDataFrameは以下の5種類．
#
# - table.station：station_data
# - table.status：status_data
# - table.trip：trip_data
# - table.weather：weather_data
# - table.feature：table.tripにtable.stationとtable.weatherの必要な情報を結合したDataFrame
#
# ＊結合前の各CSVファイルにもアクセスできる(例：table.station_201608)

# %%
# table.ipynb
import sys
import notebookutil as nbu
sys.meta_path.append(nbu.NotebookFinder())
import table

# その他に必要なモジュール(機械学習用のモジュールは使用時に読み込む)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 可視化
# 目的：非稼働状態(bikes_available = 0, docks_available = 0)である時間が長いstationの特定
# bikes_available = 0：利用可能な自転車が存在しないため機会損失につながる.
# docks_available = 0：自転車過多. 返却ができないためUXも悪い.
# bikes_available = const：trip.ipynbで考察

# %% [markdown]
# ### 各stationの1日あたりの非稼働状態である時間(min)の集計
# → まずは最も非稼働状態である時間が長いstation70について分析する

# %%
# installationからの日数
days = table.station[["station_id","installation"]].copy()
days["Days"] = (pd.Timestamp("2016-08-31") - days["installation"]).dt.days
days = days.drop("installation", axis=1)
days = days.set_index("station_id")
days.reset_index(level=0, inplace=True)

# bikes_available, docks_available=0の合計時間(min)
no_bikes = (table.status[table.status.bikes_available == 0].groupby("station_id").size()).to_frame("No Bikes")
no_docks = (table.status[table.status.docks_available == 0].groupby("station_id").size()).to_frame("No Docks")
non_working = no_bikes.join(no_docks).fillna(0)
non_working["Total"] = non_working["No Bikes"] + non_working["No Docks"]
non_working["station_id"] = non_working.index
non_working = non_working.reset_index(level=["station_id"], drop=True)
non_working= non_working[["station_id", "No Bikes", "No Docks", "Total"]]

# daysとnonworkingを結合
non_working = pd.merge(non_working, days, on="station_id")
non_working["No Bikes"] = non_working["No Bikes"] / non_working["Days"] 
non_working["No Docks"] = non_working["No Docks"] / non_working["Days"] 
non_working["Total"] = non_working["Total"] / non_working["Days"] 
non_working = non_working.rename(columns = {
    "No Bikes":"No_Bikes(min/day)", "No Docks":"No_Docks(min/day)", "Total":"No_Both(min/day)"
})
non_working = non_working.drop(["Days"], axis=1)

# 非稼働状態の時間が長い順にソート
non_working = non_working.sort_values(by=["No_Both(min/day)"], ascending = False)

# 可視化
a = non_working.plot.scatter(x='No_Bikes(min/day)',y='No_Docks(min/day)', figsize=(7, 7), title="Unavailable hours", color="dodgerblue")

# 各要素にラベルを表示
for k, v in non_working.iterrows():
    a.annotate(v[0], xy=(v[1],v[2]), size=7.5)

# DataFrameの表示
non_working = non_working.set_index("station_id")
non_working.head()
# Out:
#             No_Bikes(min/day)  No_Docks(min/day)  No_Both(min/day)
# station_id
# 70                  29.168488          39.234062         68.402550
# 73                  28.691682          29.938517         58.630199
# 54                  20.882514          35.884335         56.766849
# 60                  30.036430          23.202186         53.238616
# 48                  32.698543          15.322404         48.020947

# %% [markdown]
# ### stationの状態にその日の天候情報を結合したDataFrame(weather_status)を作成

# %%
# DataFrame1(status)
station_id = 70 # 最も非稼働時間が長いstation_id = 70について分析．
status = table.status[table.status.station_id == station_id].copy()
status["time"] = pd.to_datetime(status.time)
status["Date"] =  list(map(lambda x: x.date(), status["time"]))
status["Year and Month"] =  list(map(lambda x: x.strftime('%Y-%m'), status["time"]))
status["Date and Time"] =  list(map(lambda x: x.strftime('%Y-%m-%d %H'), status["time"]))
status["Month"] = list(map(lambda x: x.month, status["time"]))
status["Weekday"] = list(map(lambda x:x.weekday(), status["time"]))
status["Horidays"] = (status["Weekday"] <= 4).astype(int)
status["Time"] = list(map(lambda x:x.hour, status["time"]))
status = status.drop_duplicates(["station_id", "Date and Time"])
status = status.set_index("Date")

# DataFrame2(weather)
landmark = table.station.landmark[table.station.station_id == station_id].values[0]
weather = table.weather[table.weather.landmark == landmark].copy()
weather.rename(columns = {"PDT":"Date"}, inplace=True)
weather["Date"] = list(map(lambda x:x.date(), weather["Date"])) 
weather = weather.set_index("Date")

# 結合
weather_status = status.join(weather).drop("station_id", axis=1)

# 総dock数に占めるavailablebike数を求める
weather_status["docks_total"] = weather_status["bikes_available"] + weather_status["docks_available"]
weather_status["bikes_available_ratio"] = weather_status["bikes_available"] / weather_status["docks_total"]
weather_status = weather_status.drop(["bikes_available", "docks_available", "docks_total"], axis=1)

weather_status.head()
# Out:
#                           time Year and Month  Date and Time  Month  Weekday  \
# Date
# 2013-08-29 2013-08-29 12:06:01        2013-08  2013-08-29 12      8        3
# 2013-08-29 2013-08-29 13:00:02        2013-08  2013-08-29 13      8        3
# 2013-08-29 2013-08-29 14:00:01        2013-08  2013-08-29 14      8        3
# 2013-08-29 2013-08-29 15:00:02        2013-08  2013-08-29 15      8        3
# 2013-08-29 2013-08-29 16:00:01        2013-08  2013-08-29 16      8        3
#
#             Horidays  Time  Max TemperatureC  Mean TemperatureC  \
# Date
# 2013-08-29         1    12         23.333333               20.0
# 2013-08-29         1    13         23.333333               20.0
# 2013-08-29         1    14         23.333333               20.0
# 2013-08-29         1    15         23.333333               20.0
# 2013-08-29         1    16         23.333333               20.0
#
#             Min TemperatureC          ...            Min VisibilityMiles  \
# ...

# %%
# 分析するデータの指定
s_or_l= "l" # s：station, l：landmark, others: all data
search_list = {"s":table.station.station_id.values, "l":table.station.landmark.unique()}[s_or_l]

for element in search_list:
    if s_or_l == "s":
        station_id = element 
        landmark = "" # landmark =""のとき全てのlandmark
    elif s_or_l == "l":
        station_id = 0 # id=0のとき全てのstation
        landmark = element #['', 'San Jose', 'San Francisco', 'Palo Alto', 'Mountain View', 'Redwood City']
    else:
        station_id = 0
        landmark = ""   

    sub_title = "" # グラフのtitleに使用

    if station_id != 0: # station_idの指定がある場合
        ctype_count = table.features[(table.features["Start ID"] == station_id) | (table.features["End ID"] == station_id)].copy()
        sub_title = f"station:{station_id}" 
    elif  landmark != '' and station_id == 0: # landmarkの指定がある場合(station_id != 0のとき無効)
        ctype_count = table.features[(table.features["Start Landmark"] == landmark) | (table.features["End Landmark"] == landmark)].copy()
        sub_title = f"landmark:{landmark}" 
    else:
        ctype_count = table.features.copy()
        sub_title = "All data" 

    ctype_count = ctype_count.groupby("CType").size()
    ctype_count.plot(kind="bar",  figsize=(8, 5), title=f"CustomerType-Count ({sub_title})", color=[["orange", "dodgerblue"]])
#     plt.legend(["Annual","24hour or 3day"])
    plt.ylabel("Count")
    plt.xlabel("Customer type")
    plt.xticks([0 ,1], ["Annual","24hour or 3day"], rotation=0)
    plt.show()

# %% [markdown]
# ### bikes_available_ratioのヒストグラム

# %%
weather_status["bikes_available_ratio"].hist(color ="dodgerblue")

# %% [markdown]
# ### 各変数とbikes_available_ratioの関係を可視化

# %%
qualitative_variables = ["Month", "Weekday", "Horidays", "Time", "CloudCover", "Events"]
for variable in qualitative_variables:      
    x_y = weather_status[[variable, "bikes_available_ratio"]]     
    x_y.groupby(variable).mean().plot(color="dodgerblue", ylim=(0, 1))
    plt.ylabel("bikes abailable ratio")
    plt.show()

# %%
weather_status.head()
# Out:
#                           time Year and Month  Date and Time  Month  Weekday  \
# Date
# 2013-08-29 2013-08-29 12:06:01        2013-08  2013-08-29 12      8        3
# 2013-08-29 2013-08-29 13:00:02        2013-08  2013-08-29 13      8        3
# 2013-08-29 2013-08-29 14:00:01        2013-08  2013-08-29 14      8        3
# 2013-08-29 2013-08-29 15:00:02        2013-08  2013-08-29 15      8        3
# 2013-08-29 2013-08-29 16:00:01        2013-08  2013-08-29 16      8        3
#
#             Horidays  Time  Max TemperatureC  Mean TemperatureC  \
# Date
# 2013-08-29         1    12         23.333333               20.0
# 2013-08-29         1    13         23.333333               20.0
# 2013-08-29         1    14         23.333333               20.0
# 2013-08-29         1    15         23.333333               20.0
# 2013-08-29         1    16         23.333333               20.0
#
#             Min TemperatureC          ...            Min VisibilityMiles  \
# ...

# %%
weather_status_sub = weather_status.copy()
# 時間帯ごとに分類．　(-10:00 → 0， 10:00 - 15:00 → 1, 15:00-:2)
weather_status_sub.loc[weather_status_sub["Time"] < 10, "Time"] = 0
weather_status_sub.loc[weather_status_sub["Time"] >= 15, "Time"] = 2
weather_status_sub.loc[weather_status_sub["Time"]>= 10, "Time"] = 1 # weather_status_sub = weather_status_sub.reset_index(level=["Time"]) # Timeをインデックスからカラムに
weather_status_sub.head()
# Out:
#                           time Year and Month  Date and Time  Month  Weekday  \
# Date
# 2013-08-29 2013-08-29 12:06:01        2013-08  2013-08-29 12      8        3
# 2013-08-29 2013-08-29 13:00:02        2013-08  2013-08-29 13      8        3
# 2013-08-29 2013-08-29 14:00:01        2013-08  2013-08-29 14      8        3
# 2013-08-29 2013-08-29 15:00:02        2013-08  2013-08-29 15      8        3
# 2013-08-29 2013-08-29 16:00:01        2013-08  2013-08-29 16      8        3
#
#             Horidays  Time  Max TemperatureC  Mean TemperatureC  \
# Date
# 2013-08-29         1     1         23.333333               20.0
# 2013-08-29         1     1         23.333333               20.0
# 2013-08-29         1     1         23.333333               20.0
# 2013-08-29         1     2         23.333333               20.0
# 2013-08-29         1     2         23.333333               20.0
#
#             Min TemperatureC          ...            Min VisibilityMiles  \
# ...

# %%
corr = weather_status_sub.corr()
corr["abs"] = corr["bikes_available_ratio"].abs()
corr = corr.sort_values("abs", ascending=False) #.drop("abs", axis=1)
pd.DataFrame(corr["bikes_available_ratio"])
# Out:
#                            bikes_available_ratio
# bikes_available_ratio                   1.000000
# Horidays                               -0.139436
# Weekday                                 0.125663
# Time                                   -0.117445
# Min TemperatureC                       -0.057368
# Mean TemperatureC                      -0.049528
# Mean Dew PointC                        -0.048426
# Min Dew PointC                         -0.047246
# Max Dew PointC                         -0.041152
# Max TemperatureC                       -0.033068
# WindDirDegrees                         -0.030685
# CloudCover                             -0.030471
# Max Sea Level PressureIn                0.029407
# Mean Sea Level PressureIn               0.022933
# Min Sea Level PressureIn                0.020260
# Events                                 -0.016665
# Mean Humidity                          -0.014495
# Min Humidity                           -0.013537
# ...

# %%
max_mean_min = ["Max", "Mean", "Min"][1]

quantitative_variables = [
    "TemperatureC", "Dew PointC", "Humidity", "Sea Level PressureIn", 
    "VisibilityMiles", "Wind SpeedMPH", "WindDirDegrees", "PrecipitationMM"
]

for quantitative_variable in quantitative_variables:
    variable = f"{max_mean_min} {quantitative_variable}"
    if quantitative_variable == 'WindDirDegrees' or quantitative_variable == "PrecipitationMM":
        variable = quantitative_variable
    ax = weather_status[[
        "Year and Month",  
        "bikes_available_ratio"
    ]].groupby("Year and Month").mean().plot(kind="bar", color="dodgerblue", figsize=(15, 5))
    
    weather_status[["Year and Month", variable]].groupby("Year and Month").mean().plot(
        figsize=(15, 5), ax=ax, secondary_y=True, color="orange", linewidth=4, legend=True, rot=90
    ) # rot:軸のメモリを回転
    
    ax.set_ylabel('bikes_available_ratio')
    plt.ylabel(f'{variable}')
    plt.show()

# %% [markdown]
# ### bikes_available_ratioの分布を確認

# %%
weather_status["bikes_available_ratio"].hist(color = "dodgerblue")
plt.xlabel("Bikes available ratio")
plt.ylabel("Count")
plt.title('Distribution of bikes available ratio')

# %% [markdown]
# ## 機械学習

# %%
# 分類
from sklearn.linear_model import LogisticRegression # ロジスティック回帰
from sklearn.neighbors import  KNeighborsClassifier # k-NN
from sklearn.tree import  DecisionTreeClassifier # 決定木
from sklearn.ensemble import RandomForestClassifier  # ランダムフォレスト
from sklearn.svm import SVC  # SVM
from sklearn.ensemble import BaggingClassifier # バギング
from sklearn.ensemble import AdaBoostClassifier # アダブースティング
from sklearn.metrics import f1_score

classification_models = [
    LogisticRegression(),
    KNeighborsClassifier(), # BaggingClassifier(KNeighborsClassifier(),max_samples=0.5, max_features=0.5),
    DecisionTreeClassifier(), # criterion='entropy',max_depth=5), 
    RandomForestClassifier(), 
    SVC(), #C=100, gamma=1), #kernel="rbf",C=2), 
    AdaBoostClassifier(learning_rate=1.0)
]

# %% [markdown]
# ## 分類

# %% [markdown]
# ### 特徴量をカラムに持つDataFrameを作成

# %% [markdown]
# ####    クラスタリング

# %%
from sklearn.cluster import KMeans

n = 4 # クラスター数

available_ratio = pd.DataFrame(weather_status["bikes_available_ratio"]).copy()

# random_state固定

kmeans = KMeans(init='random',n_clusters=n,random_state=0)
kmeans.fit(pd.DataFrame(weather_status["bikes_available_ratio"])) 

available_ratio["cl_nm"] = kmeans.labels_


boundary1 = available_ratio.groupby("cl_nm").describe()["bikes_available_ratio", "min"].sort_values().reset_index(drop=True)[1]
boundary2 = available_ratio.groupby("cl_nm").describe()["bikes_available_ratio", "min"].sort_values().reset_index(drop=True)[2]
boundary3 = available_ratio.groupby("cl_nm").describe()["bikes_available_ratio", "min"].sort_values().reset_index(drop=True)[3]

variables = qualitative_variables + list(map(lambda x:max_mean_min + " " + x  , quantitative_variables[:-2])) + quantitative_variables[-2:]
variables.append("Max Gust SpeedMPH")
variables.append("bikes_available_ratio")
features = weather_status[variables].copy()

# 　目的変数のbikes_available_ratioをカテゴリーに分ける． この分け方で精度結構変わる
features.loc[features["bikes_available_ratio"] >= boundary3, "bikes_available_ratio"] = 4 # 過多
features.loc[features["bikes_available_ratio"] <= boundary1, "bikes_available_ratio"] = 1 #  不足
features.loc[features["bikes_available_ratio"] <= boundary2, "bikes_available_ratio"] = 2 #  少なめ
features.loc[features["bikes_available_ratio"] < 1, "bikes_available_ratio"] = 3 # 　多め

features.head()
# Out:
#             Month  Weekday  Horidays  Time  CloudCover  Events  \
# Date
# 2013-08-29      8        3         1    12         4.0       4
# 2013-08-29      8        3         1    13         4.0       4
# 2013-08-29      8        3         1    14         4.0       4
# 2013-08-29      8        3         1    15         4.0       4
# 2013-08-29      8        3         1    16         4.0       4
#
#             Mean TemperatureC  Mean Dew PointC  Mean Humidity  \
# Date
# 2013-08-29               20.0        14.444444           75.0
# 2013-08-29               20.0        14.444444           75.0
# 2013-08-29               20.0        14.444444           75.0
# 2013-08-29               20.0        14.444444           75.0
# 2013-08-29               20.0        14.444444           75.0
#
#             Mean Sea Level PressureIn  Mean VisibilityMiles  \
# Date
# 2013-08-29                      30.02                  10.0
# 2013-08-29                      30.02                  10.0
# ...

# %% [markdown]
# ### RFによる重要な特徴量の抽出

# %%
X = features.drop(["bikes_available_ratio", "Max Gust SpeedMPH"], axis=1) #Max Gust SpeedMPHはNaNあり．
y = features["bikes_available_ratio"]

# 訓練データとテストデータに分割
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

clf = RandomForestClassifier()
clf.fit(X_train, y_train)
print("train:", clf.score(X_train, y_train))
print("tets:", clf.score(X_test, y_test))

importances = clf.feature_importances_
indi = np.argsort(importances)[::-1]

label = np.array(X.columns) 

# 訓練データとテストデータに分割
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
        
plt.bar(range(X_train.shape[1]),importances[indi], color="dodgerblue")
plt.xticks(range(X_train.shape[1]),label[indi], rotation=90) 
plt.grid(True)
# Out:
# train: 0.983135391924
# tets: 0.740642219267

# %% [markdown]
# ### weatherの特徴量の主成分分析
# 過学習

# %%
import pandas as pd

# 標準化のためのモジュール
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_breast_cancer

# PCA
from sklearn.decomposition import PCA

# クラスター数
cluster_num = 1

weather_sub = weather.drop("landmark", axis=1).dropna()

sc = StandardScaler()
sc.fit(weather_sub)
weather_scaled = sc.transform(weather_sub)

pca = PCA(n_components=cluster_num)
pca.fit(weather_scaled)
weather_pca = pca.transform(weather_scaled)

weather_sub = weather_sub.reset_index(level=0)
weather_status_new = pd.concat([weather_sub, pd.DataFrame(weather_pca)], axis=1).set_index("Date")

weather_status_new = weather_status_new.join(weather_status[["Month",  "Weekday", "Horidays","Time", "bikes_available_ratio"]])

if cluster_num == 1:
    weather_status_new.rename(columns={0:"Weather main ingredient"}, inplace=True)
    weather_status_new = weather_status_new[["Month",  "Weekday", "Horidays","Time","Weather main ingredient", "bikes_available_ratio"]]
    X = weather_status_new[["Time","Weekday", "Weather main ingredient" ]]
elif cluster_num == 2:
    weather_status_new.rename(columns={0:"Weather main ingredient1", 1:"Weather main ingredient2"}, inplace=True)
    weather_status_new = weather_status_new[[
        "Month",  "Weekday", "Horidays","Time","Weather main ingredient1", "Weather main ingredient2", "bikes_available_ratio"
    ]]
    X = weather_status_new[["Time","Weekday", "Weather main ingredient1","Weather main ingredient2" ]]

# 目的変数のbikes_available_ratioをカテゴリーに分ける． この分け方で精度結構変わる
weather_status_new.loc[weather_status_new["bikes_available_ratio"] >= boundary3, "bikes_available_ratio"] = 4 # 過多
weather_status_new.loc[weather_status_new["bikes_available_ratio"] <= boundary1, "bikes_available_ratio"] = 1 #  不足
weather_status_new.loc[weather_status_new["bikes_available_ratio"] <= boundary2, "bikes_available_ratio"] = 2 #  少なめ
weather_status_new.loc[weather_status_new["bikes_available_ratio"] < 1, "bikes_available_ratio"] = 3 #  多め

y = weather_status_new["bikes_available_ratio"]

# 訓練データとテストデータに分割
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

# 標準化
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# 過学習チェック
for model in classification_models[:-1]:
    clf = model.fit(X_train, y_train)
    print(clf.__class__.__name__)
    print("train:", clf.score(X_train, y_train))
    print("test:", clf.score(X_test, y_test))
    print()
# Out:
# LogisticRegression
# train: 0.321505708115
# test: 0.318549942152
#
# KNeighborsClassifier
# train: 0.633755013885
# test: 0.454454300039
#
# DecisionTreeClassifier
# train: 1.0
# test: 0.620671037408
#
# RandomForestClassifier
# train: 0.958269052761
# test: 0.442576166602
#
# SVC
# train: 0.513961740204
# test: 0.497647512534

# %% [markdown]
# ### 決定木で過学習対策
# 汎用性能高くない

# %%
# クラス数が1のとき
if cluster_num ==  1:
    clf =DecisionTreeClassifier(max_depth=15, max_features=3) 
    clf = clf.fit(X_train, y_train)
    print("DecisionTreeClassifier")
    print("train score:", clf.score(X_train, y_train))
    print("test score:", clf.score(X_test, y_test))
    print()
elif cluster_num == 2:
    clf = RandomForestClassifier(max_depth = 15, n_estimators=25, max_features=2, min_samples_leaf = 2) 
    clf = clf.fit(X_train, y_train)
    print("RandomForestClassifier")
    print("train score:", clf.score(X_train, y_train))
    print("test score:", clf.score(X_test, y_test))
# Out:
# DecisionTreeClassifier
# train score: 0.779929034249
# test score: 0.570227535673

# %% [markdown]
# ### 試行錯誤による特徴量抽出
# "Time", "Weekday", "Mean Sea Level PressureIn", "WindDirDegrees", "Mean Humidity", "Mean TemperatureC", "Mean Dew PointC" で randomforest 0.81
#
# "Mean Wind SpeedMPH", "CloudCover" #, "Month"も加えると0.807 monthけしても同じ．
#
# "Mean Wind SpeedMPH"を消すと0.80
#
# "Mean TemperatureC"：変化小さい．

# %%
from sklearn import cross_validation

X = features[[
    "Time", "Weekday", "WindDirDegrees", "Mean Sea Level PressureIn","Mean Humidity", "Mean TemperatureC" 
]]
y = features["bikes_available_ratio"]

# 訓練データとテストデータに分割
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# 標準化
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)


# 過学習チェック
for model in classification_models[:-1]:
    clf = model.fit(X_train, y_train)
    print(clf.__class__.__name__)
    print("train:", clf.score(X_train, y_train))
    print("test:", clf.score(X_test, y_test))
    print()
# Out:
# LogisticRegression
# train: 0.32432304038
# test: 0.320539616188
#
# KNeighborsClassifier
# train: 0.810118764846
# test: 0.670340110203
#
# DecisionTreeClassifier
# train: 1.0
# test: 0.685540566217
#
# RandomForestClassifier
# train: 0.985700712589
# test: 0.734182025461
#
# SVC
# train: 0.545320665083
# test: 0.524035721072

# %% [markdown]
# ### 交差検証
# スコアは安定してる．

# %%
from sklearn import cross_validation

clf = RandomForestClassifier() #max_depth = 15, n_estimators=25, max_features=2, min_samples_leaf = 2)
shuffle = cross_validation.KFold(len(X), n_folds=5, shuffle=True, random_state=0)
scores = cross_validation.cross_val_score(clf, X, y, cv=shuffle)
print("cross_val_score")
print (scores)
# Out:
# cross_val_score
# [ 0.73475204  0.72563177  0.72772183  0.73052071  0.73850247]

# %% [markdown]
# ### ランダムフォレストで過学習対策
# 過学習はましになったが， 汎化性能は落ちた？

# %%
# RF
from sklearn.metrics import f1_score
% matplotlib inline
import matplotlib.pyplot as plt

clf = RandomForestClassifier(max_depth = 15, n_estimators=25, max_features=2, min_samples_leaf = 2)  # n_estimators=253, min_samples_split = 5
clf = clf.fit(X_train, y_train)
print("RandomForestClassifier(max_depth = 15, n_estimators=25, max_features=2, min_samples_leaf = 2)")
print("train score:", clf.score(X_train, y_train))
print("test score:", clf.score(X_test, y_test))

from sklearn import cross_validation

clf = RandomForestClassifier(max_depth = 15, n_estimators=25, max_features=2, min_samples_leaf = 2)
shuffle = cross_validation.KFold(len(X), n_folds=5, shuffle=True, random_state=0)
scores = cross_validation.cross_val_score(clf, X, y, cv=shuffle)
print("cross_val_score", scores)
# Out:
# RandomForestClassifier(max_depth = 15, n_estimators=25, max_features=2, min_samples_leaf = 2)
# train score: 0.840380047506
# test score: 0.701501045031
# cross_val_score [ 0.69884097  0.69390082  0.70435113  0.70714557  0.71037628]

# %% [markdown]
# ### 交差検証
# 精度は安定している

# %%
from sklearn import cross_validation

clf = RandomForestClassifier(max_depth = 15, n_estimators=25, max_features=2, min_samples_leaf = 2)
shuffle = cross_validation.KFold(len(X), n_folds=5, shuffle=True, random_state=0)
scores = cross_validation.cross_val_score(clf, X, y, cv=shuffle)
print (scores)
# Out:
# [ 0.71119134  0.69827095  0.71100133  0.70296465  0.7099962 ]

# %% [markdown]
# ### 各スコア

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

model = RandomForestClassifier(n_estimators=56, min_samples_split = 3)
clf = model.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print("適合率：", precision_score(y_true=y_test,y_pred=y_pred , average='macro')) 
print("再現率：", recall_score(y_true=y_test,y_pred=y_pred, average='macro')) 
print("F1score：", f1_score(y_test[:len(y_pred)], y_pred, average='macro'))
# Out:
# 適合率： 0.740093074051
# 再現率： 0.745935050465
# F1score： 0.741929857233

# %% [markdown]
# ### 再びランダムフォレストにおける特徴量の重要度を比較

# %%
model = RandomForestClassifier(n_estimators=56, min_samples_split = 3)
clf = model.fit(X_train, y_train)
print(clf.score(X_test, y_test))

importances = model.feature_importances_
indi = np.argsort(importances)[::-1]

label = np.array(X.columns) 

plt.bar(range(X_train.shape[1]),importances[indi], color="dodgerblue")
plt.xticks(range(X_train.shape[1]),label[indi], rotation=90) 
plt.grid(True)
# Out:
# 0.749572487175

# %% [markdown]
# ### confusion matrix
# (0, 1)を減らしたい

# %%
from sklearn.metrics import confusion_matrix
clf =   RandomForestClassifier(max_depth = 15, n_estimators=25, max_features=2, min_samples_leaf = 2)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("score:", clf.score(X_test, y_test))
print()
pd.DataFrame(confusion_matrix(y_test, y_pred),
             index=[["実際"]*4, ["不足", "少なめ", "多め", "過多"]], 
             columns=[["予測"]*4, ["不足", "少なめ", "多め", "過多"]]
            )
# Out:
# score: 0.700741022231
#          予測
#          不足  少なめ   多め    過多
# 実際 不足   850  122   23    11
#    少なめ  339  575  156   146
#    多め    89  143  928   285
#    過多    36   51  174  1335

# %% [markdown]
# ### 木を出力

# %%
# 学習した結果をGraphvizが認識できる形式にして出力する
from sklearn import tree
clf =  DecisionTreeClassifier(max_depth=31).fit(X_train, y_train)
with open('graph.dot', 'w') as f:
    f = tree.export_graphviz(clf, out_file=f)

# %%
ls
# Out:
# README.md                main.ipynb               table.ipynb
# SUB(地図分析).ipynb      map.ipynb                test.ipynb
# __pycache__/             notebookutil.py          trip.ipynb
# graph.dot                station.ipynb            user.ipynb
# graph.pdf                status.ipynb

# %%
# %%bash
# dot -Tpdf graph.dot -o graph.pdf

# %%
ls
# Out:
# README.md                main.ipynb               table.ipynb
# SUB(地図分析).ipynb      map.ipynb                test.ipynb
# __pycache__/             notebookutil.py          trip.ipynb
# graph.dot                station.ipynb            user.ipynb
# graph.pdf                status.ipynb

# %% [markdown]
# ### ROC曲線

# %%
# 必要なモジュール
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp

features_roc = features.copy()
# features_roc.bikes_available_ratio = features_roc.bikes_available_ratio.replace(1, 0).replace(4, 0).replace(2,1).replace(3,1)

X = features_roc[[
    "Time", "Weekday", "WindDirDegrees", "Mean Sea Level PressureIn", "Mean Humidity",  "Mean TemperatureC" 
]]
y = features_roc["bikes_available_ratio"]

# ラベル
# y = label_binarize(y, classes=[0, 1])


# X = X.values.reshape(-1, 1)
y = y.reshape(-1, 1) #values.

n_classes = y.shape[1]

random_state = np.random.RandomState(0)
n_samples, n_features = X.shape
X = np.c_[X, random_state.randn(n_samples, 200 * n_features)]


# 訓練データとテストデータに分割
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# 標準化
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)
# Out:
# /Users/Shintaro/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:21: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

clf =  RandomForestClassifier(n_estimators=56, min_samples_split = 3) #OneVsRestClassifier(RandomForestClassifier()) #n_estimators=56, min_samples_split = 3))

clf.fit(X_train, y_train) #.predict_proba(X_test)
y_test_roc = np.array(y_test).reshape(-1, 1)
y_test_roc = (2 <= y_test_roc) & (y_test_roc <= 3)

# y_test_roc = list(map(int, y_test_roc))

y_pred_roc = clf.predict(X_test)
y_pred_roc = (2 <= y_pred_roc) & (y_pred_roc <= 3)

print("適合率:%.3f" % precision_score(y_true=y_test_roc,y_pred=y_pred_roc))
print("再現率:%.3f" % recall_score(y_true=y_test_roc,y_pred=y_pred_roc))
print("F1値:%.3f" % f1_score(y_true=y_test_roc,y_pred=y_pred_roc))

clf.score(X_train, y_train)
# Out:
# /Users/Shintaro/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# 適合率:0.530
# 再現率:0.501
# F1値:0.515
# 1.0

# %%
y_score = clf.predict_proba(X_test) 
y_score
# Out:
# array([[ 0.28571429,  0.26785714,  0.24107143,  0.20535714],
#        [ 0.08035714,  0.25892857,  0.34821429,  0.3125    ],
#        [ 0.11607143,  0.1875    ,  0.25892857,  0.4375    ],
#        ...,
#        [ 0.17857143,  0.30357143,  0.23511905,  0.2827381 ],
#        [ 0.20238095,  0.32142857,  0.24404762,  0.23214286],
#        [ 0.14732143,  0.32142857,  0.34375   ,  0.1875    ]])

# %%
# ラベル

# y = label_binarize(y, classes=[0, 1])
n_classes = y.shape[1]

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-190-d8324984e5c2> in <module>()
#       8 roc_auc = dict()
#       9 for i in range(n_classes):
# ---> 10     fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
#      11     roc_auc[i] = auc(fpr[i], tpr[i])
#
# /Users/Shintaro/anaconda/lib/python3.6/site-packages/sklearn/metrics/ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     503     """
#     504     fps, tps, thresholds = _binary_clf_curve(
# --> 505         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     506
#     507     # Attempt to drop thresholds corresponding to points in between and
#
# /Users/Shintaro/anaconda/lib/python3.6/site-packages/sklearn/metrics/ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     312              array_equal(classes, [-1]) or
# ...

# %%
# %matplotlib inline

#点のプロット
plt.plot(fpr[0], tpr[0], color='red',lw= 2, label='ROC curve (area = %0.2f)' % roc_auc[0])
plt.plot([0, 1], [0, 1], color='black', lw= 2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

#ラベルなど
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="best")

# %%
# original
# prob_result = pd.DataFrame(clf.predict_proba(X_test))

# prob_result["result"] = prob_result.idxmax(axis=1)+1
# prob_result.loc[(prob_result[[0, 1, 2]].max(axis=1) < 0.7) & (prob_result[0] > 0.3), "result"] = 1
# prob_result.head(13)

# %% [markdown]
# ### グリッドサーチ
# knn:kを大きくするほど下がった

# %%
# RF
from sklearn.metrics import f1_score
n_list = [1, 10, 30, 50, 100, 250, 500]
score_list = []
for n in n_list:
    clf = RandomForestClassifier(n_estimators=n) # n_estimators:作る決定木の数の指定
    clf = clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    score_list.append(f1_score(y_test[:len(y_pred)], y_pred, average='macro'))
    
# 可視化
% matplotlib inline
import matplotlib.pyplot as plt
print(np.round(score_list,4))
plt.plot(n_list, score_list)

# %%
# DT
score_list = []
best_score = 0
best_d = 0
for d in range(1, 50):
    clf = DecisionTreeClassifier(max_depth=d).fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    score_list.append(clf.score(X_test, y_test))
    if clf.score(X_test, y_test) > best_score:
        best_score = clf.score(X_test, y_test)
        best_d = d
print(f"d:{best_d} \n score:{best_score}")
plt.plot(range(1, 50), score_list)

# %% [markdown]
# ## 回帰
#
# 1時間ごととかにみてて，相関が低いから

# %%
# model

# 重回帰分析
from sklearn.linear_model import LinearRegression
# リッジ回帰
from sklearn.linear_model import Ridge
# k近傍法
from sklearn.neighbors import  KNeighborsRegressor   
# KernelRidge
# from sklearn.kernel_ridge import KernelRidge    
# DT
from sklearn.tree import DecisionTreeRegressor
# RF
from sklearn.ensemble import RandomForestRegressor
# SVM
from sklearn.svm import SVR

regression_models = [
    LinearRegression(), Ridge(), KNeighborsRegressor(), DecisionTreeRegressor(), RandomForestRegressor(), SVR()
]

# %%
X = weather_status[["Time", "Weekday"]] #, "Max TemperatureC"]] #.values.reshape(-1, 1)
y = weather_status["bikes_available_ratio"].values

# 訓練データとテストデータに分割
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# 標準化

# %%
for model in regression_models:
    clf = model.fit(X_train, y_train)
    print(clf.__class__.__name__)
    print("train:", clf.score(X_train, y_train))
    print("test:", clf.score(X_test, y_test))
    print()
# Out:
# LinearRegression
# train: 0.0284862990518
# test: 0.0266331491841
#
# Ridge
# train: 0.0284862990495
# test: 0.0266331803952
#
# KNeighborsRegressor
# train: 0.409132678273
# test: 0.423957438572
#
# DecisionTreeRegressor
# train: 0.515665386608
# test: 0.517820115423
#
# RandomForestRegressor
# train: 0.515275274709
# test: 0.517872213554
#
# SVR
# train: 0.50810489399
# test: 0.511643106708

# %% [markdown]
# ### 主成分分析

# %%
import pandas as pd

# 標準化のためのモジュール
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_breast_cancer

# PCA
from sklearn.decomposition import PCA

# クラスター数
cluster_num = 1

weather_sub = weather.drop("landmark", axis=1).dropna()

sc = StandardScaler()
sc.fit(weather_sub)
weather_scaled = sc.transform(weather_sub)

pca = PCA(n_components=cluster_num)
pca.fit(weather_scaled)
weather_pca = pca.transform(weather_scaled)

weather_sub = weather_sub.reset_index(level=0)
weather_status_new = pd.concat([weather_sub, pd.DataFrame(weather_pca)], axis=1).set_index("Date")

weather_status_new = weather_status_new.join(weather_status[["Month",  "Weekday", "Horidays","Time", "bikes_available_ratio"]])

if cluster_num == 1:
    weather_status_new.rename(columns={0:"Weather main ingredient"}, inplace=True)
    weather_status_new = weather_status_new[["Month",  "Weekday", "Horidays","Time","Weather main ingredient", "bikes_available_ratio"]]
    X = weather_status_new[["Time","Weekday", "Weather main ingredient" ]]
elif cluster_num == 2:
    weather_status_new.rename(columns={0:"Weather main ingredient1", 1:"Weather main ingredient2"}, inplace=True)
    weather_status_new = weather_status_new[[
        "Month",  "Weekday", "Horidays","Time","Weather main ingredient1", "Weather main ingredient2", "bikes_available_ratio"
    ]]
    X = weather_status_new[["Time","Weekday", "Weather main ingredient1","Weather main ingredient2" ]]

# # 目的変数のbikes_available_ratioをカテゴリーに分ける． この分け方で精度結構変わる
# weather_status_new.loc[weather_status_new["bikes_available_ratio"] >= boundary3, "bikes_available_ratio"] = 4 # 過多
# weather_status_new.loc[weather_status_new["bikes_available_ratio"] <= boundary1, "bikes_available_ratio"] = 1 #  不足
# weather_status_new.loc[weather_status_new["bikes_available_ratio"] <= boundary2, "bikes_available_ratio"] = 2 #  少なめ
# weather_status_new.loc[weather_status_new["bikes_available_ratio"] < 1, "bikes_available_ratio"] = 3 #  多め

y = weather_status_new["bikes_available_ratio"]

# 訓練データとテストデータに分割
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

# 標準化
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# 過学習チェック
for model in regression_models[:]:
    clf = model.fit(X_train, y_train)
    print(clf.__class__.__name__)
    print("train:", clf.score(X_train, y_train))
    print("test:", clf.score(X_test, y_test))
    print()
# Out:
# LinearRegression
# train: 0.0314234589901
# test: 0.0300238013379
#
# Ridge
# train: 0.0314234587998
# test: 0.0300239282496
#
# KNeighborsRegressor
# train: 0.632615680337
# test: 0.433744884852
#
# DecisionTreeRegressor
# train: 1.0
# test: 0.430419983553
#
# RandomForestRegressor
# train: 0.928759926879
# test: 0.603125329561
#
# SVR
# train: 0.489758506498
# test: 0.468142038257
